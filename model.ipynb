# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import wfdb

# %%
record=wfdb.rdrecord('tpehgt_n001')
plt.rcParams['figure.figsize'] = [20, 20]
wfdb.plot_wfdb(record=record, title='Not pregnant')

# %%
record=wfdb.rdrecord('tpehgt_p001')
plt.rcParams['figure.figsize'] = [20, 20]
wfdb.plot_wfdb(record=record, title='Preterm')

# %%
record=wfdb.rdrecord('tpehgt_p003')
plt.rcParams['figure.figsize'] = [20, 20]
wfdb.plot_wfdb(record=record, title='Preterm')

# %%
record=wfdb.rdrecord('tpehgt_t001')
plt.rcParams['figure.figsize'] = [20, 20]
wfdb.plot_wfdb(record=record, title='Term')

# %%
record=wfdb.rdrecord('tpehgt_t003')
plt.rcParams['figure.figsize'] = [20, 20]
wfdb.plot_wfdb(record=record, title='Term')

# %%
#convert all the files into one csv file


path = 'C:/Users/rehan/Desktop/term-preterm-ehg-dataset-with-tocogram-1.0.0/'
for file in os.listdir(path):
    if file.endswith(".dat"):
        record = wfdb.rdrecord(path+file[:-4])
        df = pd.DataFrame(record.p_signal)
        df.to_csv(path+file[:-4]+'.csv',header=record.sig_name, index=True)
        print(file)
df.head()
# Out:
# tpehgt_n001.dat
# tpehgt_n002.dat
# tpehgt_n003.dat
# tpehgt_n004.dat
# tpehgt_n005.dat
# tpehgt_p001.dat
# tpehgt_p002.dat
# tpehgt_p003.dat
# tpehgt_p004.dat
# tpehgt_p005.dat
# tpehgt_p006.dat
# tpehgt_p007.dat
# tpehgt_p008.dat
# tpehgt_p009.dat
# tpehgt_p010.dat
# tpehgt_p011.dat
# tpehgt_p012.dat
# tpehgt_p013.dat
# tpehgt_t001.dat
# tpehgt_t002.dat
# tpehgt_t003.dat
# tpehgt_t004.dat
# tpehgt_t005.dat
# tpehgt_t006.dat
# tpehgt_t007.dat
# tpehgt_t008.dat
# tpehgt_t009.dat
# tpehgt_t010.dat
# tpehgt_t011.dat
# tpehgt_t012.dat
# tpehgt_t013.dat
#           0         1         2         3         4         5         6  \
# 0  0.008547  0.000000 -0.074481 -0.020757 -0.168498 -0.042735  0.004884
# 1  0.008547  0.002442 -0.074481 -0.042735 -0.168498 -0.092796  0.004884
# 2  0.009768  0.003663 -0.074481 -0.040293 -0.167277 -0.087912  0.004884
# 3  0.010989  0.003663 -0.074481 -0.034188 -0.168498 -0.072039  0.004884
# 4  0.012210  0.004884 -0.074481 -0.034188 -0.168498 -0.073260  0.006105
#
#           7
# 0  0.002442
# 1  0.003663
# 2  0.003663
# 3  0.003663
# 4  0.003663

# %%
path = 'C:/Users/rehan/Desktop/term-preterm-ehg-dataset-with-tocogram-1.0.0/'
for file in os.listdir(path):
    if file.endswith(".atr"):
        record = wfdb.rdrecord(path+file[:-4])
        df2 = pd.DataFrame(record.p_signal)
        df2.to_csv(path+file[:-4]+'.csv', index=True)
        print(file)
df2.head()
# Out:
# tpehgt_n001.atr
# tpehgt_n002.atr
# tpehgt_n003.atr
# tpehgt_n004.atr
# tpehgt_n005.atr
# tpehgt_p001.atr
# tpehgt_p002.atr
# tpehgt_p003.atr
# tpehgt_p004.atr
# tpehgt_p005.atr
# tpehgt_p006.atr
# tpehgt_p007.atr
# tpehgt_p008.atr
# tpehgt_p009.atr
# tpehgt_p010.atr
# tpehgt_p011.atr
# tpehgt_p012.atr
# tpehgt_p013.atr
# tpehgt_t001.atr
# tpehgt_t002.atr
# tpehgt_t003.atr
# tpehgt_t004.atr
# tpehgt_t005.atr
# tpehgt_t006.atr
# tpehgt_t007.atr
# tpehgt_t008.atr
# tpehgt_t009.atr
# tpehgt_t010.atr
# tpehgt_t011.atr
# tpehgt_t012.atr
# tpehgt_t013.atr
#           0         1         2         3         4         5         6  \
# 0  0.008547  0.000000 -0.074481 -0.020757 -0.168498 -0.042735  0.004884
# 1  0.008547  0.002442 -0.074481 -0.042735 -0.168498 -0.092796  0.004884
# 2  0.009768  0.003663 -0.074481 -0.040293 -0.167277 -0.087912  0.004884
# 3  0.010989  0.003663 -0.074481 -0.034188 -0.168498 -0.072039  0.004884
# 4  0.012210  0.004884 -0.074481 -0.034188 -0.168498 -0.073260  0.006105
#
#           7
# 0  0.002442
# 1  0.003663
# 2  0.003663
# 3  0.003663
# 4  0.003663
